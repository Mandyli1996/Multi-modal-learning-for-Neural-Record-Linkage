# %%
import pickle as pkl

with open('Deeper_img_decom4.map', 'rb') as f:
    Deeper_img_decom4 = pkl.load(f)
    
with open('Deeper_img_decom5.map', 'rb') as f:
    Deeper_img_decom5 = pkl.load(f)
    
with open('Deeper_img_decom6.map', 'rb') as f:
    Deeper_img_decom6 = pkl.load(f)
    
with open('history_baselinecosine.map', 'rb') as f:
    baselinecosine = pkl.load(f)
    
with open('history_baselineinverse_l1.map', 'rb') as f:
    baselineinverse_l1 = pkl.load(f)

with open('history_mymodel_imgvbi_50.map', 'rb') as f:
    imgvbi_50 = pkl.load(f)

with open('history_mymodel_imgvbi.map', 'rb') as f:
    mymodel_imgvbi = pkl.load(f)

# %%
with open('history_baseline_withimg.map', 'rb') as f:
    baseline_img = pkl.load(f)

# %%
img_deep  = {}
img_advance = {}
for key, val in imgvbi_50.items():
    img_deep[key] = []
    img_advance[key] = []

# %%
# loss: 0.3322 - acc: 0.8599 - precision: 0.8702 - f1_score: 0.8873 - auroc: 0.9338 - val_loss: 0.5131 - val_acc: 0.7806 - val_precision: 0.8126 - val_f1_score: 0.8228 - val_auroc: 0.8485
# loss: 0.3678 - acc: 0.8415 - precision: 0.8515 - f1_score: 0.8733 - auroc: 0.9173 - val_loss: 0.4908 - val_acc: 0.7801 - val_precision: 0.7783 - val_f1_score: 0.8327 - val_auroc: 0.8533
# cos
# loss: 0.4110 - acc: 0.8181 - precision: 0.8270 - f1_score: 0.8559 - auroc: 0.8940 - val_loss: 0.4733 - val_acc: 0.7799 - val_precision: 0.8352 - val_f1_score: 0.8157 - val_auroc: 0.8533
# loss: 0.4632 - acc: 0.7886 - precision: 0.7956 - f1_score: 0.8352 - auroc: 0.8606 - val_loss: 0.4970 - val_acc: 0.7598 - val_precision: 0.7452 - val_f1_score: 0.8243 - val_auroc: 0.8476
# loss: 0.5425 - acc: 0.7367 - precision: 0.7453 - f1_score: 0.7997 - auroc: 0.7938 - val_loss: 0.4889 - val_acc: 0.7642 - val_precision: 0.7587 - val_f1_score: 0.8236 - val_auroc: 0.8367
                                        
img_advance['acc'] = [ 0.7367,0.7886,0.8181,0.8415 ,0.8599]
img_advance['val_acc'] = [0.7642, 0.7598,0.7799,0.7801 ,0.7806]
img_advance['loss'] = [ 0.5425,0.4632,0.4110,0.3678,0.3322]
img_advance['val_loss'] = [0.4889,0.4970,0.4733 ,0.4908  ,0.5131]
img_advance['precision'] = [0.7453,0.7956,0.8270 ,0.8515, 0.8702]
img_advance['val_precision'] = [0.7587, 0.7452, 0.8352 , 0.7783 ,0.8126]
img_advance['f1_score'] = [0.7997, 0.8352, 0.8559 ,0.8733, 0.8873]
img_advance['val_f1_score'] = [0.8236, 0.8243, 0.8157,0.8327,0.8228]
img_advance['auroc'] = [0.7938,0.8606,0.8940,0.9173 , 0.9338]
img_advance['val_auroc'] = [0.8367, 0.8476,0.8533,0.8533 ,0.8485]

# %%
# loss: 0.4209 - acc: 0.8050 - precision: 0.8688 - f1_score: 0.8335 - auroc: 0.8765 - val_loss: 0.5312 - val_acc: 0.7506 - val_precision: 0.7884 - val_f1_score: 0.7987 - val_auroc: 0.8267
# loss: 0.4494 - acc: 0.7876 - precision: 0.8319 - f1_score: 0.8241 - auroc: 0.8628 - val_loss: 0.4996 - val_acc: 0.7582 - val_precision: 0.8293 - val_f1_score: 0.7937 - val_auroc: 0.8273
# loss: 0.4891 - acc: 0.7592 - precision: 0.7884 - f1_score: 0.8071 - auroc: 0.8380 - val_loss: 0.4956 - val_acc: 0.7561 - val_precision: 0.8084 - val_f1_score: 0.7979 - val_auroc: 0.8262                         
# loss: 0.5579 - acc: 0.7093 - precision: 0.7275 - f1_score: 0.7780 - auroc: 0.7772 - val_loss: 0.5102 - val_acc: 0.7480 - val_precision: 0.8264 - val_f1_score: 0.7830 - val_auroc: 0.8194                                       
#cosine

img_deep['acc'] = [ 0.7093, 0.7592, 0.7876, 0.8050]
img_deep['val_acc'] = [0.7480 ,0.7561,0.7582, 0.7506]
img_deep['loss'] = [ 0.5579, 0.4891, 0.4494, 0.4209]
img_deep['val_loss'] = [0.5102, 0.4956, 0.4996,0.5312]
img_deep['precision'] = [0.7275,0.7884, 0.8319, 0.8688]
img_deep['val_precision'] = [0.8264,0.8084, 0.8293, 0.7884 ]
img_deep['f1_score'] = [0.7780, 0.8071,0.8241, 0.8335]
img_deep['val_f1_score'] = [0.7830, 0.7979,0.7937 ,0.7987]
img_deep['auroc'] = [0.7772, 0.8380, 0.8628, 0.8765]
img_deep['val_auroc'] = [0.8194, 0.8262, 0.8273, 0.8267]

# %%
import numpy as np
table_1 = {}
table = {}
models = [baselinecosine,baselineinverse_l1, Deeper_img_decom4, Deeper_img_decom5, imgvbi_50, mymodel_imgvbi, img_advance, img_deep]
names = ['baseline1_cos', 'baseline1_cos_l1', 'baseline2_cos','decom_cos', 'decom_cos_l1', 'hybrid_cos', 'vbi_50']
index = []
for i in ['val_auroc','val_acc','val_loss', 'val_precision', 'val_f1_score','val_recall']:
    table_1[i] = []
    table[i] = {}
    for j in range(len(names)):
        table[i][names[j]] = 0
        #print(type(table[names[i]]))
        if i == 'val_recall':
            val_recall = np.array(models[j]['val_f1_score'])*np.array(models[j]['val_precision'])/(2*np.array(models[j]['val_precision']) - np.array(models[j]['val_f1_score']))
            table_1[i].append(val_recall[index[j]])
            table[i][names[j]] = val_recall[index[j]]
        elif i == 'val_auroc':
            temp = models[j][i].index(max(models[j][i]))
            index.append(temp)
            table_1[i].append(max(models[j][i]))
            table[i][names[j]] = max(models[j][i])
        else:
            table[i][names[j]] = models[j][i][index[j]]
            table_1[i].append(models[j][i][index[j]])
        #table[names[i]][j] = max(models[i][j])

# %%
heat_map = []
for i in ['val_auroc','val_acc', 'val_precision', 'val_f1_score','val_recall']:
    heat_map.append( np.array(table_1[i]) )
heat_map = np.array(heat_map)
heat_map = np.matrix(heat_map).T
import seaborn as sns
ax = sns.heatmap(heat_map, vmin=0.45, vmax=0.87,center=0.7,annot=True,cmap="YlGnBu")

# %%
table
# Out:
# {'val_auroc': {'baseline1_cos': 0.8379489074264911,
#   'baseline1_cos_l1': 0.8382195270159118,
#   'baseline2_cos': 0.8600733094554268,
#   'decom_cos': 0.8551810835138554,
#   'decom_cos_l1': 0.856080727358296,
#   'hybrid_cos': 0.8578125558706139,
#   'vbi_50': 0.8533},
#  'val_acc': {'baseline1_cos': 0.7701889881856537,
#   'baseline1_cos_l1': 0.7616680358508227,
#   'baseline2_cos': 0.7784387825842068,
#   'decom_cos': 0.7846836460939468,
#   'decom_cos_l1': 0.7844617889861936,
#   'hybrid_cos': 0.7845439591560583,
#   'vbi_50': 0.7799},
#  'val_loss': {'baseline1_cos': 0.49490484007578356,
#   'baseline1_cos_l1': 0.49824112558227734,
#   'baseline2_cos': 0.49706361931959137,
#   'decom_cos': 0.48255750970362443,
#   'decom_cos_l1': 0.4647164641096637,
#   'hybrid_cos': 0.46117004433810566,
#   'vbi_50': 0.4733},
#  'val_precision': {'baseline1_cos': 0.8375261749638822,
#   'baseline1_cos_l1': 0.852965422841684,
#   'baseline2_cos': 0.7616294465522535,
# ...

# %%
heat_map
# Out:
# array([array({'baseline1_cos': 0.8379489074264911, 'baseline1_cos_l1': 0.8382195270159118, 'baseline2_cos': 0.8600733094554268, 'decom_cos': 0.8551810835138554, 'decom_cos_l1': 0.856080727358296, 'hybrid_cos': 0.8578125558706139, 'vbi_50': 0.8533},
#       dtype=object),
#        array({'baseline1_cos': 0.7701889881856537, 'baseline1_cos_l1': 0.7616680358508227, 'baseline2_cos': 0.7784387825842068, 'decom_cos': 0.7846836460939468, 'decom_cos_l1': 0.7844617889861936, 'hybrid_cos': 0.7845439591560583, 'vbi_50': 0.7799},
#       dtype=object),
#        array({'baseline1_cos': 0.49490484007578356, 'baseline1_cos_l1': 0.49824112558227734, 'baseline2_cos': 0.49706361931959137, 'decom_cos': 0.48255750970362443, 'decom_cos_l1': 0.4647164641096637, 'hybrid_cos': 0.46117004433810566, 'vbi_50': 0.4733},
#       dtype=object),
# ...

# %%
import numpy as np
table_1 = {}
models = [baselinecosine,baselineinverse_l1, Deeper_img_decom4, Deeper_img_decom5, imgvbi_50, mymodel_imgvbi, img_advance, img_deep]
names = ['baseline1_cos', 'baseline1_cos_l1', 'decom_cos', 'decom_cos_l1', 'vbi_50', 'vbi_bi', 'hybrid_cos', 'baseline2_cos']
for i in ['val_auroc','val_loss']:
    table_1[i] = []
    
    for j in range(len(names)):
        #print(type(table[names[i]]))
        if i =='val_loss':
            table_1[i].append( min(models[j][i]))
        elif i == 'val_recall':
            val_recall = np.array(models[j]['val_f1_score'])*np.array(models[j]['val_precision'])/(2*np.array(models[j]['val_precision']) - np.array(models[j]['val_f1_score']))
            table_1[i].append(max(val_recall))
        else:
            table_1[i].append( max(models[j][i]))
        #table[names[i]][j] = max(models[i][j])

# %%
table_1
# Out:
# {'val_acc': [0.7701889881856537,
#   0.7684634341112198,
#   0.787428099695737,
#   0.7846836460939468,
#   0.7844617889861936,
#   0.7847904667760274,
#   0.7806,
#   0.7582],
#  'val_loss': [0.49490484007578356,
#   0.49140673797445994,
#   0.4663232896988178,
#   0.4816636033692904,
#   0.4647164641096637,
#   0.46117004433810566,
#   0.4733,
#   0.4956],
#  'val_precision': [0.8764934704069247,
#   0.852965422841684,
#   0.8781909591278156,
#   0.8813046220364333,
#   0.8230397641974523,
#   0.826934460304741,
#   0.8352,
#   0.8293],
#  'val_f1_score': [0.8046353878440511,
#   0.8120297533200344,
#   0.836601574529047,
#   0.8302816447624313,
#   0.8250274655939982,
#   0.8251870040584547,
#   0.8327,
#   0.7987],
#  'val_auroc': [0.8379489074264911,
#   0.8382195270159118,
#   0.8600733094554268,
#   0.8551810835138554,
#   0.856080727358296,
#   0.8578125558706139,
#   0.8533,
#   0.8273],
#  'val_recall': [0.7944884012558353,
#   0.9039520214640522,
#   0.9469784278901203,
# ...

# %%
table_1
fig, axes = plt.subplots(2,2,figsize=(10, 15))

#axes[0][0].plot( table_1['val_acc'],label= 'val_acc')
axes[0][0].plot(table_1['val_loss'],  label= 'val_loss')
axes[0][0].plot(table_1['val_precision'], label='val_precision')
axes[0][0].plot(table_1['val_f1_score'], label='val_f1_score')
axes[0][0].plot(table_1['val_auroc'],label= 'val_auroc')

for i in range(len(axes)):
    #ylabel = 
    for j in range(len(axes[0])):
        axes[i][j].legend()
        axes[i][j].grid(True)
        axes[i][j].set(ylabel='precentage')
        axes[i][j].set(xlabel='models')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
table_1['val_auroc']
# Out:
# [0.8379489074264911,
#  0.8382195270159118,
#  0.8600733094554268,
#  0.8551810835138554,
#  0.856080727358296,
#  0.8578125558706139,
#  0.8533,
#  0.8273]

# %%
num_list1 = [0.8379489074264911, 0.8600733094554268, 0.856080727358296, 0.8533, 0.8273]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,12))
names_list =  ['baseline1_cos', 'decom_cos', 'vbi_50', 'hybrid_cos', 'baseline2_cos']


#num_list = table_1['val_auroc'].copy()


plt.bar(range(len(num_list1)), num_list1, color = 'rgb', tick_label = names_list)
plt.ylim(0.825,0.861)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.xlabel('Models', fontsize=40)
plt.ylabel('auroc', fontsize=40)
# Out:
# Text(0, 0.5, 'auroc')

# %%
table_1
#fig, axes = plt.subplots(2,2,figsize=(10, 15))

#axes[0][0].plot( table_1['val_acc'],label= 'val_acc')
plt.figure(figsize=(8,10))
plt.plot(table_1['val_loss'],  label= 'val_loss')
plt.plot(table_1['val_precision'], label='val_precision')
plt.plot(table_1['val_f1_score'], label='val_f1_score')
plt.plot(table_1['val_auroc'],label= 'val_auroc')
plt.plot(table_1['val_recall'],label= 'val_recall')

for i in range(len(axes)):
    #ylabel = 
    for j in range(len(axes[0])):
        plt.legend()
        plt.grid(True)
        plt.ylabel('precentage')
        plt.xlabel('models')

# %%
table
# Out:
# {'val_acc': {'baseline1_cos': 0.7701889881856537,
#   'baseline1_cos_l1': 0.7684634341112198,
#   'decom_cos': 0.787428099695737,
#   'decom_cos_l1': 0.7846836460939468,
#   'vbi_50': 0.7844617889861936,
#   'vbi_bi': 0.7847904667760274,
#   'hybrid_cos': 0.7806,
#   'baseline2_cos': 0.7582},
#  'val_loss': {'baseline1_cos': 0.5479140696509901,
#   'baseline1_cos_l1': 0.5923716918846184,
#   'decom_cos': 0.6143770111371184,
#   'decom_cos_l1': 0.5895231858373374,
#   'vbi_50': 0.5367301491409809,
#   'vbi_bi': 0.5314982293469062,
#   'hybrid_cos': 0.5131,
#   'baseline2_cos': 0.5312},
#  'val_precision': {'baseline1_cos': 0.8764934704069247,
#   'baseline1_cos_l1': 0.852965422841684,
#   'decom_cos': 0.8781909591278156,
#   'decom_cos_l1': 0.8813046220364333,
#   'vbi_50': 0.8230397641974523,
#   'vbi_bi': 0.826934460304741,
#   'hybrid_cos': 0.8352,
#   'baseline2_cos': 0.8293},
#  'val_f1_score': {'baseline1_cos': 0.8046353878440511,
#   'baseline1_cos_l1': 0.8120297533200344,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_deeper_q3(dicc, namee):
    fig, axes = plt.subplots(3,2, figsize=(15, 25))
    for dic, name in zip(dicc, namee):
        val_acc = dic['val_acc']
        acc = dic['acc']
        val_loss = dic['val_loss']
        loss = dic['loss']
        val_precision = np.array(dic['val_precision'])
        precision = np.array(dic['precision'])
        val_f1_score = np.array(dic['val_f1_score'])
        f1_score = np.array(dic['f1_score'])
        val_auroc = np.array(dic['val_auroc'])
        auroc = dic['auroc']
        recall = f1_score*precision/(2*precision - f1_score)
        val_recall = val_f1_score*val_precision/(2*val_precision - val_f1_score)
        
        
        axes[0][0].plot(loss, label= name+'_loss')
        axes[0][1].plot(val_loss, label= name+'_val_loss')
        axes[1][0].plot(acc, label=name+ '_acc')
        axes[1][1].plot(val_acc, label=name+ '_val_acc')
        axes[2][0].plot(precision, label=name+ '_precision')
        axes[2][1].plot(val_precision, label=name+ '_val_precision') 

        for i in range(len(axes)):
            ylabel = ['loss', 'acc', 'precision'][i]
            for j in range(len(axes[0])):
                axes[i][j].legend()
                axes[i][j].grid(True)
                axes[i][j].set(ylabel=ylabel)
                axes[i][j].set(xlabel='epoches')
        #return fig, axes

    
import matplotlib.pyplot as plt
import numpy as np

def plot_deeper_h3(dicc, namee):
    fig, axes = plt.subplots(3,2, figsize=(15, 25))
    for dic, name in zip(dicc, namee):
        val_acc = dic['val_acc']
        acc = dic['acc']
        val_loss = dic['val_loss']
        loss = dic['loss']
        val_precision = np.array(dic['val_precision'])
        precision = np.array(dic['precision'])
        val_f1_score = np.array(dic['val_f1_score'])
        f1_score = np.array(dic['f1_score'])
        val_auroc = np.array(dic['val_auroc'])
        auroc = dic['auroc']
        recall = f1_score*precision/(2*precision - f1_score)
        val_recall = val_f1_score*val_precision/(2*val_precision - val_f1_score)
        
        axes[0][0].plot(f1_score, label=name+ '_f1_score')
        axes[0][1].plot(val_f1_score, label=name+ '_val_f1_score')
        axes[1][0].plot(auroc, label=name+ '_auroc')
        axes[1][1].plot(val_auroc, label=name+ '_val_auroc')
        axes[2][0].plot(recall, label=name+ '_recall')
        axes[2][1].plot(val_recall, label=name+ '_val_recall')        

        for i in range(len(axes)):
            ylabel = ['f1_score', 'auroc', 'recall'][i]
            for j in range(len(axes[0])):
                axes[i][j].legend()
                axes[i][j].grid(True)
                axes[i][j].set(ylabel=ylabel)
                axes[i][j].set(xlabel='epoches')
        #return fig, axes

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_deeper_q3(dicc, namee):
    fig, axes = plt.subplots(2,2, figsize=(20, 15))
    for dic, name in zip(dicc, namee):
        val_acc = dic['val_acc']
        acc = dic['acc']
        val_loss = dic['val_loss']
        loss = dic['loss']
        val_precision = np.array(dic['val_precision'])
        precision = np.array(dic['precision'])
        val_f1_score = np.array(dic['val_f1_score'])
        f1_score = np.array(dic['f1_score'])
        val_auroc = np.array(dic['val_auroc'])
        auroc = dic['auroc']
        recall = f1_score*precision/(2*precision - f1_score)
        val_recall = val_f1_score*val_precision/(2*val_precision - val_f1_score)
        
        
        axes[0][0].plot(loss, label= name+'_train_loss')
        axes[0][1].plot(val_loss, label= name+'_val_loss')
        axes[1][0].plot(auroc, label=name+ '_train_auroc')
        axes[1][1].plot(val_auroc, label=name+ '_val_auroc')

        for i in range(len(axes)):
            ylabel = ['loss','auroc'][i]
            for j in range(len(axes[0])):
                axes[i][j].legend()
                axes[i][j].grid(True)
                axes[i][j].set(ylabel=ylabel)
                axes[i][j].set(xlabel='epoches')
        #plt.xticks(fontsize=30)
        #return fig, axes


def plot_deeper_h3(dicc, namee):
    fig, axes = plt.subplots(2,2, figsize=(15, 25))
    for dic, name in zip(dicc, namee):
        val_acc = dic['val_acc']
        acc = dic['acc']
        val_loss = dic['val_loss']
        loss = dic['loss']
        val_precision = np.array(dic['val_precision'])
        precision = np.array(dic['precision'])
        val_f1_score = np.array(dic['val_f1_score'])
        f1_score = np.array(dic['f1_score'])
        val_auroc = np.array(dic['val_auroc'])
        auroc = dic['auroc']
        recall = f1_score*precision/(2*precision - f1_score)
        val_recall = val_f1_score*val_precision/(2*val_precision - val_f1_score)
        

   

        for i in range(len(axes)):
            ylabel = ['auroc'][i]
            for j in range(len(axes[0])):
                axes[i][j].legend()
                axes[i][j].grid(True)
                axes[i][j].set(ylabel=ylabel)
                axes[i][j].set(xlabel='epoches')
        #return fig, axes

# %%
def plot_deeper_q3(dicc, namee):
    for dic, name in zip(dicc, namee):
        val_acc = dic['val_acc']
        acc = dic['acc']
        val_loss = dic['val_loss']
        loss = dic['loss']
        val_precision = np.array(dic['val_precision'])
        precision = np.array(dic['precision'])
        val_f1_score = np.array(dic['val_f1_score'])
        f1_score = np.array(dic['f1_score'])
        val_auroc = np.array(dic['val_auroc'])
        auroc = dic['auroc']
        recall = f1_score*precision/(2*precision - f1_score)
        val_recall = val_f1_score*val_precision/(2*val_precision - val_f1_score)
        
        #plt.figure(figsize=(20,12))
        #axes[0][0].plot(loss, label= name+'_train_loss')
        #axes[0][1].plot(val_loss, label= name+'_val_loss')
        #plt.plot(auroc, label=name+ '_train_auroc')
        plt.plot(val_auroc, label=name+ '_val_auroc')

        for i in range(1):
            ylabel = ['auroc'][i]
            for j in range(len(axes[0])):
                plt.legend()
                plt.grid(True)
                plt.xlabel(ylabel+'_val',fontsize=25 )
                plt.ylabel('epoches',fontsize=25)
                plt.xticks(fontsize=15)
                plt.yticks(fontsize=15)

# %%
plot_deeper_q3([baselinecosine,baselineinverse_l1, Deeper_img_decom4, Deeper_img_decom5, imgvbi_50, mymodel_imgvbi, img_advance, img_deep], ['baseline1_cos', 'baseline1_cos_l1', 'decom_cos', 'decom_cos_l1', 'vbi_50', 'vbi_bi', 'hybrid_cos', 'baseline2_cos'])

# %%
plot_deeper_h3([baselinecosine,baselineinverse_l1, Deeper_img_decom4, Deeper_img_decom5, imgvbi_50, mymodel_imgvbi, img_advance, img_deep], ['baseline1_cos', 'baseline1_cos_l1', 'decom_cos', 'decom_cos_l1', 'vbi_50', 'vbi_bi', 'hybrid_cos', 'baseline2_cos'])
